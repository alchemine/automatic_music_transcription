# %%
import music21

# %%
music21.converter.parse("tinyNotation: 4/4 c4 d e f g a b c'").show("midi")

# %%
from music21 import environment

path = "/Applications/MuseScore 4.app/Contents/MacOS/mscore"
environment.set("musescoreDirectPNGPath", path)

# %%
music21.converter.parse("tinyNotation: 4/4 c4 d e f g a b c'").show()

# %%
from music21.note import Note

Note("C4").show("mid")
# Out:
# The application /Applications/GarageBand.app cannot be opened for an unexpected reason, error=Error Domain=NSCocoaErrorDomain Code=260 "The file “GarageBand.app” couldn’t be opened because there is no such file." UserInfo={NSURL=file:///Applications/GarageBand.app, NSFilePath=/Applications/GarageBand.app, NSUnderlyingError=0x131907260 {Error Domain=NSPOSIXErrorDomain Code=2 "No such file or directory"}}
